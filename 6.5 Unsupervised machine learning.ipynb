# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import folium
import json
import pylab as pl 
import threadpoolctl
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.cluster import KMeans

# %%
Data = r"C:\Users\anu10\OneDrive\Documents\Advanced Analytics and Dashboard Achievement 6"

# %%
df = pd.read_csv(os.path.join(Data,"kc_house_data.csv"  ))

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
print(df.dtypes)
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %%
# Drop the 'date' column
df1 = df.drop('date', axis=1)

# %%
df1.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
# Assuming 'df1' is your DataFrame
# Handle categorical variables using one-hot encoding
df1_encoded = pd.get_dummies(df1)

# Specify the range of clusters you want to try
num_cl = range(1, 10)

# Create a list of KMeans models for each number of clusters
kmeans = [KMeans(n_clusters=i, random_state=42) for i in num_cl]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %%
num_cl = range(1,10) 
kmeans = [KMeans(n_clusters=i) for i in num_cl]
# Create the k-means clusters and calculate scores
score = [-kmeans[i].fit(df1).score(df1) for i in range(len(kmeans))]

# Plot the elbow curve
plt.plot(num_cl, score, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Score (Negative Inertia)')
plt.title('Elbow Curve for K-Means Clustering')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17060\4033401289.py in <module>
#       2 kmeans = [KMeans(n_clusters=i) for i in num_cl]
#       3 # Create the k-means clusters and calculate scores
# ----> 4 score = [-kmeans[i].fit(df1).score(df1) for i in range(len(kmeans))]
#       5
#       6 # Plot the elbow curve
#
# ~\AppData\Local\Temp\ipykernel_17060\4033401289.py in <listcomp>(.0)
#       2 kmeans = [KMeans(n_clusters=i) for i in num_cl]
#       3 # Create the k-means clusters and calculate scores
# ----> 4 score = [-kmeans[i].fit(df1).score(df1) for i in range(len(kmeans))]
#       5
#       6 # Plot the elbow curve
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1184
#    1185             # run a k-means once
# -> 1186             labels, inertia, centers, n_iter_ = kmeans_single(
# ...

# %%
# Assuming 'df1' is your DataFrame
# Check if df1 is not None
if df1 is not None:
    # Handle categorical variables using one-hot encoding
    df1_encoded = pd.get_dummies(df1)

    # Check for missing values
    if df1_encoded.isnull().sum().any():
        # Handle missing values (impute or drop)
        df1_encoded = df1_encoded.dropna()  # Replace with your preferred method

    # Specify the range of clusters you want to try
    num_cl = range(1, 10)

    # Create a list of KMeans models for each number of clusters
    kmeans = [KMeans(n_clusters=i, random_state=42) for i in num_cl]

    # Create the k-means clusters and calculate scores
    score = [-kmeans[i].fit(df1_encoded).score(df1_encoded) for i in range(len(kmeans))]

    # Plot the elbow curve
    plt.plot(num_cl, score, marker='o')
    plt.xlabel('Number of Clusters (k)')
    plt.ylabel('Score (Negative Inertia)')
    plt.title('Elbow Curve for K-Means Clustering')
    plt.show()
else:
    print("DataFrame 'df1' is None.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17060\764052779.py in <module>
#      17
#      18     # Create the k-means clusters and calculate scores
# ---> 19     score = [-kmeans[i].fit(df1_encoded).score(df1_encoded) for i in range(len(kmeans))]
#      20
#      21     # Plot the elbow curve
#
# ~\AppData\Local\Temp\ipykernel_17060\764052779.py in <listcomp>(.0)
#      17
#      18     # Create the k-means clusters and calculate scores
# ---> 19     score = [-kmeans[i].fit(df1_encoded).score(df1_encoded) for i in range(len(kmeans))]
#      20
#      21     # Plot the elbow curve
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1184
#    1185             # run a k-means once
# -> 1186             labels, inertia, centers, n_iter_ = kmeans_single(
#    1187                 X,
# ...

# %%
#import threadpoolctl

with threadpoolctl.threadpool_limits(limits=1, user_api="openmp"):
    # your code here
    num_cl = range(1,10)
    kmeans = [KMeans(n_clusters=i,random_state=42) for i in num_cl]
    # create the k-means clusters
    score = [-kmeans[i].fit(df1).score(df1) for i in range(len(kmeans))]
    # Plot the elbow curve
    plt.plot(num_cl, score, marker='o')
    plt.xlabel('Number of Clusters (k)')
    plt.title('Elbow Curve for K-Means Clustering')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17060\1107493846.py in <module>
#       6     kmeans = [KMeans(n_clusters=i,random_state=42) for i in num_cl]
#       7     # create the k-means clusters
# ----> 8     score = [-kmeans[i].fit(df1).score(df1) for i in range(len(kmeans))]
#       9     # Plot the elbow curve
#      10     plt.plot(num_cl, score, marker='o')
#
# ~\AppData\Local\Temp\ipykernel_17060\1107493846.py in <listcomp>(.0)
#       6     kmeans = [KMeans(n_clusters=i,random_state=42) for i in num_cl]
#       7     # create the k-means clusters
# ----> 8     score = [-kmeans[i].fit(df1).score(df1) for i in range(len(kmeans))]
#       9     # Plot the elbow curve
#      10     plt.plot(num_cl, score, marker='o')
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1184
# ...

# %%
print(df1.dtypes)

# %%
print(kmeans)

# %%
print(df1.shape)

# %%
# Create the k-means object
kmeans = KMeans(n_clusters=3)

# %%
# Fit the k-means object to the data
kmeans.fit(df1)

# %%
df1['clusters'] = kmeans.fit_predict(df1)

# %%
df1.head()

# %%
df1['clusters'].value_counts()

# %%
# Plotting Price_per_Unit
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)  # Creating a subplot for Price_per_Unit
plt.scatter(df.index, df['sqft_lot'])
plt.title('price')
plt.xlabel('Index')
plt.ylabel('House price')

# %%
# Plotting Distance_to_Metro
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 2)  # Creating a subplot for Distance_to_Metro
plt.scatter(df.index, df1['sqft_lot'], c= df1['clusters'],cmap='viridis',label='clusters')
plt.title('House Price')
plt.xlabel('sqft_lot')
plt.ylabel('Price')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Assuming you have a 3D DataFrame with columns 'House age', 'Price per unit', and 'clusters'
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot in 3D
scatter = ax.scatter(df1['sqft_lot'], df1['price'], df1.index, c=df1['clusters'], cmap='viridis', label='clusters')

# Labeling the axes
ax.set_xlabel('House age')
ax.set_ylabel('House price')
ax.set_zlabel('Index')

# Adding a colorbar
cbar = plt.colorbar(scatter)
cbar.set_label('clusters')

# Display the plot
plt.title('3D Scatter Plot of House age, Price per unit, and Clusters')
plt.show()

# %%
# Assuming df is your DataFrame containing the relevant columns
# 'Number of convenience stores', 'Distance to the nearest MRT station', 'House age', and 'Clusters'
# Adjust column names accordingly

# Relabel clusters from numbers to color names
df1['clusters'] = df1['clusters'].replace({0: 'Pink', 1: 'Purple', 2: 'Dark Purple'})

# Group by clusters and calculate descriptive statistics
cluster_stats = df1.groupby('clusters').agg({
    'price': ['median', 'mean', 'std'],
    'sqft_lot': ['median', 'mean', 'std'],
    'sqft_living': ['median', 'mean', 'std']
}).reset_index()

# Print the descriptive statistics
print(cluster_stats)

# Additional observations and assumptions
dark_purple_cluster = df1[df1['clusters'] == 'Dark Purple']

# Median number of shops
median_shops_dark_purple = dark_purple_cluster['price'].median()

# Median age
median_age_dark_purple = dark_purple_cluster['sqft_lot'].median()

# Median distance to metro stations
median_distance_dark_purple = dark_purple_cluster['sqft_living'].median()

# %% [markdown]
# yes, this steps will be helpful for future steps of analytics pipeline.

# %%
# Assuming df1 is your DataFrame
num_clusters = 6  # Set the number of clusters

# Extract relevant features for clustering
features_for_clustering = df1[['yr_built', 'price']]

# Perform KMeans clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
df1['cluster'] = kmeans.fit_predict(features_for_clustering)

# Plotting scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='yr_built', y='price', data=df1, hue='cluster', palette='deep')
plt.title('KMeans Clustering')
plt.xlabel('Year Built')
plt.ylabel('Price')
plt.show()

# %%
# Assuming df is your DataFrame for encoding
df_encoded = pd.get_dummies(df1, columns=['sqft_lot'])
# Plotting count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='view', data=df_encoded)
plt.title('Count Plot for Encoded "view" Column')
plt.xlabel('Encoded View')
plt.ylabel('Count')
plt.show()

# %%
# Assuming df1 is your DataFrame for encoding
df1_encoded = pd.get_dummies(df1, columns=['sqft_lot'])

# Plotting count plot
plt.figure(figsize=(10, 6))
sns.countplot(x='view', data=df1_encoded)
plt.title('Count Plot for Encoded "sqft_lot" Column')
plt.xlabel('Encoded sqft_lot')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='bedrooms',data=df1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df1 is your DataFrame
# Assuming 'Date' is the column representing time

# Set the 'Date' column as the index if it's not already
df.set_index('yr_built', inplace=True)

# Plotting time series analysis for the 'Median Number of Shops' in the 'Dark Purple' cluster
plt.figure(figsize=(10, 5))
sns.lineplot(x=df.index, y='price', data=dark_purple_cluster, label='year')
plt.xlabel('Date')
plt.ylabel('Median Number of Shops')
plt.title('Time Series Analysis: Median Number of Shops in Dark Purple Cluster Over Time')
plt.legend()
plt.show()

# Plotting time series analysis for the 'Median Age' in the 'Dark Purple' cluster
plt.figure(figsize=(10, 5))
sns.lineplot(x=df.index, y='sqft_lot', data=dark_purple_cluster, label='Median Age (Dark Purple Cluster)')
plt.xlabel('Date')
plt.ylabel('Median Age')
plt.title('Time Series Analysis: Median Age in Dark Purple Cluster Over Time')
plt.legend()
plt.show()

# Plotting time series analysis for the 'Median Distance to Metro Stations' in the 'Dark Purple' cluster
plt.figure(figsize=(10, 5))
sns.lineplot(x=df.index, y='sqft_living', data=dark_purple_cluster, label='Median Distance to Metro Stations (Dark Purple Cluster)')
plt.xlabel('Date')
plt.ylabel('Median Distance to Metro Stations')
plt.title('Time Series Analysis: Median Distance to Metro Stations in Dark Purple Cluster Over Time')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17060\100293651.py in <module>
#      10 # Plotting time series analysis for the 'Median Number of Shops' in the 'Dark Purple' cluster
#      11 plt.figure(figsize=(10, 5))
# ---> 12 sns.lineplot(x=df.index, y='price', data=dark_purple_cluster, label='year')
#      13 plt.xlabel('Date')
#      14 plt.ylabel('Median Number of Shops')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
